# %%
from pyspark.sql import SparkSession

# %%
# We create a spark session and use the spark context within the spark session because we want both dataframes and rdds

ss = SparkSession.builder.appName("DataProc").config("spark.driver.memory", "32g").config("spark.executor.memory", "32g").config("spark.executor.memoryOverhead", "32g").getOrCreate()
sc = ss.sparkContext
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/03 19:35:50 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# we load up an rdd from the paths text file
paths_rdd = sc.textFile("data/wet.paths")

# %%
# we take approximately sample_size paths from the samples rdd. path contains like 30k crawls so we don't want huge samples
sample_size = 1
sampled_paths = paths_rdd.sample(withReplacement=False, fraction=sample_size/paths_rdd.count(), seed=0)

# %%
# this is just something we need to prepend to every path so we can create it into a link to download
url_head = "https://data.commoncrawl.org/"

# %%
# now we have an rdd of just urls
urls_rdd = sampled_paths.map(lambda x: url_head + x)

# %%
urls_rdd.take(1)
# Out:
# ['https://data.commoncrawl.org/crawl-data/CC-MAIN-2025-47/segments/1762439344161.47/wet/CC-MAIN-20251115170955-20251115200955-00990.warc.wet.gz']

# %%
# we use requests to get a http response from the common crawl server
def get_request(url):
    import requests
    response = requests.get(url, stream=True)
    if response.status_code == 200:
    # Request was successful
        return response
    else:
        return None

# %%
responses_rdd = urls_rdd.map(get_request)

# %%
# we convert the responses into gzip files in memory
def get_zipped(response):
    import io
    return io.BytesIO(response.content)

# %%
zipped_files = responses_rdd.map(get_zipped)

# %%
zipped_files.take(1)

# %%
# we unzip the zipped files also within memory
def unzip(zipped):
    import gzip
    with gzip.GzipFile(fileobj=zipped) as decompressed_file:
        return decompressed_file.read()

# %%
unzipped_rdd = zipped_files.map(unzip)

# %%
type(unzipped_rdd.take(1)[0])
# Out:
# bytes

# %%
# we convert the unzipped bytes into usable strings 
str_rdd = unzipped_rdd.map(lambda x: x.decode("utf-8"))

# %%
# as you can see this is a plaintext snippet of the plaintext WET file. we need to process this string rdd to do our analysis.
# we need to strip away the description data and access just the text. ideally we get rid of line breaks and stuff like that too.
# then throw it into language detection, lda, and so on
print(str_rdd.take(1)[0][:10000])
# Out:
# WARC/1.0
# WARC-Type: warcinfo
# WARC-Date: 2025-11-21T04:06:14Z
# WARC-Filename: CC-MAIN-20251115170955-20251115200955-00990.warc.wet.gz
# WARC-Record-ID: <urn:uuid:ab28ab8c-7598-4b9c-8476-fa456e97b558>
# Content-Type: application/warc-fields
# Content-Length: 372
#
# Software-Info: ia-web-commons.3.0.1-SNAPSHOT-20251103031243
# Extracted-Date: Fri, 21 Nov 2025 04:06:14 GMT
# robots: checked via crawler-commons 1.6-SNAPSHOT (https://github.com/crawler-commons/crawler-commons)
# isPartOf: CC-MAIN-2025-47
# operator: Common Crawl Admin (info@commoncrawl.org)
# description: Wide crawl of the web for November 2025
# publisher: Common Crawl
#
#
#
# WARC/1.0
# WARC-Type: conversion
# WARC-Target-URI: http://0555st.cn/Pro/59.html
# WARC-Date: 2025-11-15T19:07:00Z
# WARC-Record-ID: <urn:uuid:89fc2355-4e3f-4f31-8c9f-fa9fdad37c7c>
# WARC-Refers-To: <urn:uuid:cb89bb7e-86bf-4c5b-b989-425af8e33cec>
# WARC-Block-Digest: sha1:RJKU4E3P7RJB25I436A3SOX25NNZS5D5
# WARC-Identified-Content-Language: zho
# Content-Type: text/plain
# Content-Length: 164400
#
# 欢乐颂第二季,穿越小说完本,盗墓笔记第二季
# 首頁
# 關(guān)于我們
# 公司簡介
# 主要合作伙伴
# 我們的使命
# 榮譽(yù)證書
# 產(chǎn)品展示
# 硫化鋅
# 鈣鋅穩(wěn)定劑
# 液體穩(wěn)定劑
# 復(fù)合穩(wěn)定劑
# 阻燃劑
# 抗沖改性劑
# 潤滑劑
# 鐳雕粉
# 立德粉
# 脫模劑
# 母粒
# 展會信息
# 研發(fā)與品控
# 資訊中心
# 公司新聞
# 行業(yè)動態(tài)
# 聯(lián)系我們
# 中文版
# English
# 硫化鋅
# 鈣鋅穩(wěn)定劑
# 液體穩(wěn)定劑
# 復(fù)合穩(wěn)定劑
# 阻燃劑
# 抗沖改性劑
# 潤滑劑
# 鐳雕粉
# 立德粉
# 脫模劑
# 母粒
# 尼龍專用阻燃協(xié)效劑FRX-A105
# 在線咨詢
# 在線咨詢
# 產(chǎn)品名稱 * :
# 電子郵箱 * :
# 聯(lián)系人 :
# 電話 :
# 咨詢內(nèi)容 :
# 驗(yàn)證碼 * :
# 提交
# 重置
# 產(chǎn)品詳情
# 產(chǎn)品概述
# ? FRX-A105在玻纖增強(qiáng)尼龍的溴銻阻燃劑體系可完全替換三氧化二銻 ，獲得比溴銻阻燃體系更加優(yōu)良 的阻燃效果和力學(xué)性能，同時具有出色的電學(xué) 、耐熱 、低析出等綜合性能 。
# ? FRX-A105為白色粉末狀，其分子結(jié)構(gòu)經(jīng)特殊優(yōu)化 ，具有耐熱穩(wěn)定好 、添加量小 、機(jī)械性能優(yōu)良 、色 澤佳 、產(chǎn)品燃燒煙密度低 、CTI（相比漏電起痕指數(shù)）值高等優(yōu)點(diǎn) 。
# ? FRX-A105符合RoHS和REACH對有害物質(zhì)的限制和禁止使用的要求 。
# 產(chǎn)品性能
# ? 下表列出值均為通過測試規(guī)范測出的典型值 ，僅供參考。
# 項(xiàng)目
# 測試標(biāo)準(zhǔn)
# 單位
# 指標(biāo)[1]
# 磷含量
# GB/T 30902
# w/%
# ≥18.0
# 水分
# GB/T 5009.36-2003
# w/%
# ≤0.5
# 粒徑D50
# GB/T 19077
# um
# 35-60
# 堆積密度
# GB/T20316.1-2009
# g/?
# 0.5-0.8
# [1] 指標(biāo)是指實(shí)驗(yàn)室平均數(shù)據(jù) ，僅用于使用時的參考，不作為產(chǎn)品的標(biāo)準(zhǔn) 。
# 包裝儲存
# 包裝：聚乙烯內(nèi)襯的25kg包裝袋 。
# 儲存：儲存及運(yùn)輸過程中的溫度建議不超過90℃ ，需密閉防潮，產(chǎn)品建議存放于干燥場所 。
# 根據(jù)上述條件存放，最短保質(zhì)期為自生產(chǎn)之日起24個月 。
# 上一頁：聚烯烴專用無鹵阻燃劑FRX-B101
# 下一頁：尼龍專用無鹵阻燃劑FRX-A101
# 熱門推薦
# 阻燃母粒 FR-MB04
# 聚酯專用阻燃協(xié)效劑FRX...
# 聚烯烴專用無鹵阻燃劑FR...
# 尼龍專用阻燃協(xié)效劑FRX...
# 尼龍專用無鹵阻燃劑FRX...
# 聚乙烯蠟 PL-105
# 硫化鋅 三氧化二銻的替代...
# 立德粉
# 公司介紹
# 關(guān)于我們
# 聯(lián)系我們
# 產(chǎn)品中心
# 硫化鋅
# 鈣鋅穩(wěn)定劑
# 液體穩(wěn)定劑
# 復(fù)合穩(wěn)定劑
# 阻燃劑
# 抗沖改性劑
# 潤滑劑
# 鐳雕粉
# 立德粉
# 脫模劑
# 母粒
# 新材料專業(yè)生產(chǎn)商
# 15萬噸產(chǎn)能
# 全球性銷售與服務(wù)網(wǎng)絡(luò)
# 高新技術(shù)企業(yè)
# 三大技術(shù)中心專業(yè)團(tuán)隊(duì)
# 科技資訊
# 公司新聞
# 行業(yè)動態(tài)
# 13360776333
# 版權(quán)所有 ? 2016 廣東鑫達(dá)新材料科技有限公司 ??粵ICP備18072545號 網(wǎng)站建設(shè)：力洋網(wǎng)絡(luò)
# 首頁
# 電話
# 短信
# 聯(lián)系
# 感谢您访问我们的网站，您可能还对以下资源感兴趣：
# 免费无码一区二区三区_xtv午夜福利女子隐私116_一女被两男吃奶玩乳尖_www.欧美中文字幕_惠民福利国产美女被遭强高潮免费网站_国产色青青网站在线观看_日韩午夜无码_亚洲欧美一二三_日韩精品人妻中文字幕在线有码_十八禁国产超污无遮挡网站
# 国产一区二区欧美亚洲一区 | 亚洲欧美国产日韩精品综合在线 | 久久精品99这里只有精品 | 久久精品国产99国产精2022 | 欧美激情日韩一区久久 | 高清久久久久 | 精品国产免费第一区久久 | 欧美bbw性色大片试看 | 亚洲精品乱码久久久久久主播 | 91短视频版在线看 | 91精品国产高清久久久久久9 | 免费无码毛片在哪里观看 | 久草免费精品视频 | 三级色网视频在线播放 | 高清综合国产中文 | 0855影视手机在线看片 | 麻豆国产第二部阿宾在线 | 亚洲成ä人片在线观看网 | 黄色app下载大全 | 高清熟女超碰一区二区 | 国产毛片一区 | 欧美激情天堂网中文在线 | 午夜免费在线视频日韩欧美 | 亚洲卡1卡2卡三卡4卡5卡6卡 | 国产麻豆放荡AV剧情演绎 | 各种无码走光视频网址 | 亚洲美女av影视 | 两个人免费观看日本高清 | 午夜人妻精品视频网 | 久久精品无遮盖又黄 | 色欲色香天天天综合网www | 在线观看欧美日本国产h | 国产无码网址 | 欧美日韩中文亚洲v在线播放 | 久久国内精品视频 | 毛耸耸亚洲熟妇性xxxx交潮喷 | 亚洲精品无码Mⅴ在线观看 | 午夜福利在线欧美 | 国产三级毛片不卡在线 | 91麻豆国产视频专区 | 日韩欧美淫一区二区 | 天天爽天天爽夜夜爽毛片 | 欧美成人亚洲综合网站 | 精品视频免费观看高清在线 | 人妻av无码系列专区首页 | 成人三级片国产a | 日本欧美中文字幕 | 免费簧网站永久在线播放国产 | 亚洲欧洲综合日韩免费视频 | 国产熟女91一区二区三区 | 久久午夜神器羞羞少妇无码 | 免费丰满鲁大师国产手机色午夜 | 红桃视频网站免费观看 | 黑人巨大中出人妻无码 | 欧美一区二区在线免费播放 | 国产免费av片在线看播放 | 黑人巨茎大战白人美女 | 欧美精品不卡一区二区三区在线观看 | 在线欧美成人免费播放 | 在线观看亚洲av日韩a∨水蜜桃 | 免费日韩一区二区三区 | 2020日本www网站不卡 | 不堪的熟女IGAO视频 | 狐狸视频黄瓜视频在线观看 | 国产成人免费观看中文性生交大片 | 欧美亚洲日韩不卡在线在线观看 | 久久精品99这里只有精品 | 免费收看人成网站 | 亚洲最新社区综合网 | 亚洲äv最新在线观看网址 | 国精品产露脸自拍 | 欧美一区二区在线网站性色 | 天天操 夜夜操 天天干 | 亚洲大片免费看蜜桃 | www.978红桃视频在线观看 | 国产精选av一区二区 | 人妻字幕字幕中文一级黄片免费 | 最爽的亂倫A片中国国产 | 日韩中文网你懂得精品一区 | 国产成人午夜福利在线小电影 | 青春草在线视频免费播放 | 久久久久久久久久久久久精品 | 国产又又色又爽三级视频 | 成人激情婷婷丁香五月天 | 中文字幕乱码中文乱码51精品 | 一级 黄 色 片免费网站 | 精品国产乱码久久久久久1区二区 | 国产在线视频92pao | 打扑克又叫疼又叫痛不盖被子 | 日本激情夜里视频在线观看 | 国产精品一区二区在线电影 | 国精品无码一区二区三区久久hv | 亚洲精品成人无限看 | 最新国模裸体精品自拍视频 | 日韩精品人妻系列无码AV东京热 | 在线观看免费人成视频播放 | 免费看女人隐私在线网站精品资源 | 国产精品三級片在线免費看 | 91短视频在线直播 | 韩国理论片妈妈的朋友 | 男男肉车纯肉无码动漫 | 92精品免费视频国产专区 | 久久精品无遮盖又黄 | 无码精品午夜在线视频观看 | 自拍 日韩 清纯 欧美 | 久久综合给合久久狠狠97 | 欧美大香线蕉线伊人久久91 | 午夜天堂成人欧美www无码 | 久久av无码大全免费版全网站 | 1区2区3区4区产品乱码芒果 | 亚洲欧美日韩中文字幕精品 | 这里都是精品在线视频播放 | 亚洲国产aⅴ美女网站 | 国产精品一区二区福利在线观看 | 杏美月在线观看一区 | 欧美色多多99热色综合 | 网友分享中文字幕女人天堂ab在线心得 | 国产综合精品swag | (愛妃精選)99久久伊人精品影院 | 这里都是精品在线视频播放 | 免费在线中文无码 | 俄罗斯精品无码一区二区三区 | 亚洲欧洲国产综合a | 一区二区三区精品偷拍 | 久久精品国产亚洲av成人 | 亚洲综合狠狠99婷婷 | 国产麻豆剧传媒精品国产av黑人 | 麻花豆剧国产MV在线看动漫 | 国产精品久久激情 | 2020国产精品香蕉在线观看 | 最新高清无码专区 | 国产韩国黑人久久久 | 久久亚洲av无码精品浪潮 | a片疯狂做爰全过的视频 | 人妻回春按摩肏到中出 | 中国精品人妻久久久久 | 国产麻豆剧传媒精品国产av黑人 | 亚洲成人av日韩 | 人妻aⅴ中文字版 | 饥渴少妇高潮视频大全 | 中国少妇人妻人做人人做人人开放 | 热久久99精品综合久久 | 亚洲色久悠悠在线观看 | 精品国产自产在线观看永久 | 国产人妻一区二区无码 | 歐洲爆乳劇情H版在線觀看 | 精品少妇无码视频69 | 一个人免费资源在线观看 | 国产一级毛片不卡中文字幕 | 果冻天美乌鸦星空传媒在线观看 | 粉嫩少妇内射浓精VIDEOS | 狠狠躁18三区二区一区丰满老熟女毛片 | 宝贝对着摄像头自己做忘羡 | 国产一级做â爰大片免费久久 | 亚洲综合狠狠99婷婷 | 91久久午夜福利网国产a | 无码海外视频在线免费播放 | 久久精品国产亚洲ąv无码 | 久久久久久精品国产亚洲 | 国产成人精品人人 | 日韩视频在线毛茸茸毛片 | 日本天堂免费网站在线观看 | 中文字幕亚洲免费看国产女女人视频免费播放 | 丰满岳跪趴高撅肥臀尤物在线观看 | 午夜免费观看一级黄色片 | 高潮呻吟国产在线播放 | 日韩欧美一二三区激情 | 欧美日韩一二三区免费大片 | 色噜噜精品视频在线观看 | 一色一伦一区二区三区色欲AV亚洲中文字幕久久 | 欧美黑人乱伦另类XXBB | 五月婷婷六月丁香在线观看 | a级片在线看日韩免费不卡 | 人妻精品一区二区三区视频免费 | 一区二区三区不卡国产免费 | 国产精品成人免费视频观看 | 精品国自产拍天天拍2024 | 亚洲精品国精品久久99热 | 国产精品黄色在线免费 | 任我爽在线精品视频免费观看 | 新超碰国产情侣久久 | 欧美精品不卡一区二区三区在线观看 | 亚洲中文字幕久无码专区 | 91国内老熟妇露脸 | 日韩国产免费无码久久久一区二区 | 精品久中文字幕人妻資源免費看 | 国产微拍精品一区视频 | 国产在线精品6699 | 一级二级A片无码高潮免费看欧美 | 性–交–黄–片直播 | 免费看高清片国产剧情 | 国产欧美影视久久 | 卡一卡2卡3卡4网站www | 国产精品午夜自在在线最熱門最齊全電影! | 国产成人精品电影在线观看91 | 久久亚洲国产成人精品老牛 | 免费播放一区二区三区 | 亚洲国产丝袜精品久久久一区二区 | 99久热只有精品视频免费看 | 玩弄了裸睡少妇人妻野战 | 精品无码久久久久久国产高潮不断 | 亚洲一卡2卡3卡4卡新区乱码 | 欧美深夜性爱网站 | 18禁拍拍拍网站免费 | 丝袜制服国产日韩欧美 | 黄色成人av午夜 | 特黄特色网站免费看 | 亚洲欧美日产在线视频 | 一级c欧美做人视频免费观看 | 四虎影视8848a四虎在线播放 | 手机在线国产午夜福利片 | 午夜福利一区二区三区无码 | 亚洲无码韩国电影大陆 | 中日韩视频在线看免费观看 | 精品黄色视频网站 | 不堪的熟女IGAO视频 | 亚洲视频一区二区三区免费在线观看 | 国产观看视频一区二区在线观看 | 欧美一区二区三区婷婷月色 | 在线中出视频网站播放 | 国产在线视频第一页 | AV第一福利大全导航 | 啊啊啊好大视频在线免费看 | 午夜在线不卡精品国产手機看片影視 | 日日人人狠狠影院 | 午夜视频在线观看91 | 亚洲三级黄色毛片在线观看 | 亚州毛色毛片免费观看 | 久久婷婷综合色拍亚洲 | 午夜男女爽爽网站在线 | 本站收藏大量国产精品国产一区二区三区 | 国内视频自拍视频网 | 亚洲日日噜噜孕妇中文字幕 | 精品国产成人国产在线网站 | 亞洲av無碼精品色午夜app | 国内少妇自拍av | 欧美一级aA片免费 | 国产曰批免费视频播放免费s | 亚洲91自拍视频在线 | 亚洲日本韩国国产一区91色欲 | 国产经典三级av在线播放 | 網友分享国产精品www夜色影视心得 | 久久青青草国产第一页在线视频观看日韩11页 | 亚洲男人的天堂A毛片在线看 | 欧美成人精品在线观看视频 | 中文字幕伦伦在线中文字 | 人妻av无码系列专区首页 | 榴莲在线观看视频国产 | 国产v亚洲v欧美v另类v | 亚洲男人AV天堂午夜在 | 国产精品一区二区网地 | 高清熟女超碰一区二区 | 午夜久久国产精品一区二区 | 一区二区免费毛片播放网 | 日本亚洲免费网站 | 亚洲一级A v无码毛片久久动漫 | 免费人成视频在线不卡 | 国产精品丝袜尤物在线观看 | 今天免费中文字幕视频 | 日韩精品新一区二区三区 | 在线播放91第一页 | 精品国产污污网站 | 日韩精品无码一区二区三区四区 | 亚洲第一日韩精品一区二区三区 | 蜜桃av无码免费一区二区 | 亚洲av先锋影音资源在线观看 | 午夜激情免费久久 | 亚洲精品一区二区三区无毒 | 国产精品午夜性爱 | 国产精品K频道欧美亚洲日韩 | 精品一区二区免费视频播放 | 西瓜视频下载日韩在线观看 | 欧美人与动交片免费播放 | 免费一级黃色录像影片 | 小说区 ...
